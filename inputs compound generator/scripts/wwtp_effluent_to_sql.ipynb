# %%
import pandas as pd 
from sqlalchemy import create_engine

# %%
path = "C:\\Users\\jsalo\\Desktop\\traca_mostres\\"

# %%
edar_data = pd.read_excel(path+'edar_data.xlsx')
edar_data.head()
# Out:
#             codi_eu codi_aca    nom_edar  poblacio_sanejada primari secundari  \
# 0  ES9080010001010E     DABR      ABRERA              63029       P        SP
# 1  ES9080140001010E     DAGF  AIGUAFREDA               4626       P        SN
# 2  ES9430050001010E     DALB     ALCOVER               4611       P        SC
# 3  ES9430090001010E     DALJ     ALFORJA               1790       P        SC
# 4  ES9170080001010E     DANG      ANGLÈS               5569       P        SP
#
#   terciari
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN

# %%
#Take columns codi_eu and nom_edar and convert to dictionary with key nom_edar and value codi_eu
edar_dict = edar_data.set_index('nom_edar')['codi_eu'].to_dict()

# %%
#Functions that read the data from the excel file and return a dataframe, parses column fecha as date
def read_data(file, edar_dict):
    df = pd.read_excel(file, parse_dates=['fecha'])
    if 'cod_eu' not in df.columns:
        df['cod_eu'] = df['nom_edar'].map(edar_dict)
    #If missing value in code_eu, take column name and look for it in edar_dict
    df['cod_eu'] = df['cod_eu'].fillna(df['nom_edar'].map(edar_dict))
    #Drop id column if exists
    if 'id' in df.columns:
        df.drop('id', axis=1, inplace=True)
    return df

# %%
#in µg/l
prtr_edars_2 = read_data(path+'prtr_edars_2.xlsx', edar_dict)
prtr_edars_2.head()
# Out:
#              nom_edar      fecha  Arsènic dissolt  Crom dissolt  \
# 0                REUS 2021-11-19              NaN           NaN
# 1  RIERA DE LA BISBAL 2022-03-10              NaN           NaN
# 2                 VIC 2022-03-10              NaN           NaN
# 3                RUBÍ 2021-10-06              NaN           NaN
# 4              PINEDA 2022-01-17              NaN           NaN
#
#    Coure dissolt  Niquel dissolt  Plom dissolt  Zinc dissolt  Tetracloroetilè  \
# 0            NaN             NaN           NaN           NaN              NaN
# 1            NaN             NaN           NaN         0.026              NaN
# 2            NaN           0.029           NaN         0.063              NaN
# 3          0.033           0.017           NaN         0.090              NaN
# 4            NaN             NaN           NaN         0.040              NaN
#
#    Triclorometà  ...   Diuron  Nonilfenols  4-t-octifenol  Nitrogen Total  \
# ...

# %%
#in µg/l
prtr_edars_1 = read_data(path+'prtr_edars.xlsx', edar_dict)
prtr_edars_1.head()
# Out:
#              cod_eu cod_aca         nom_edar      fecha  Arsènic dissolt  \
# 0  ES9081940001010E    DBSS            BESÒS 2009-01-01              3.4
# 1  ES9083010001010E    DGVC  GAVÀ/VILADECANS 2009-01-01              6.5
# 2  ES9170790005010E    DGIR           GIRONA 2009-01-01              1.4
# 3  ES9080960001010E    DGRA       GRANOLLERS 2009-01-01              1.5
# 4  ES9081050001010E    DLLL      LA LLAGOSTA 2009-01-01              1.7
#
#    Cadmi dissolt  Crom dissolt  Coure dissolt  Mercuri dissolt  \
# 0            NaN           3.9            3.0              NaN
# 1            NaN           6.6           12.9              NaN
# 2            NaN           NaN           21.3              NaN
# 3            NaN           7.8            5.2              NaN
# 4            NaN           3.6            4.3              NaN
#
#    Niquel dissolt  ...  trifenilestaño µg/l  npeoe=0  t-octilfenol  \
# 0            11.2  ...                  NaN      NaN           NaN
# ...

# %%
str_columns = ['cod_eu', 'cod_aca', 'nom_edar', 'fecha', 'codi_eu']
#If column is not in str_columns, divide by 1000 (convert to micrograms/L to milligrams/L)
prtr_edars_1.loc[:, ~prtr_edars_1.columns.isin(str_columns)] = prtr_edars_1.loc[:, ~prtr_edars_1.columns.isin(str_columns)].div(1000)
prtr_edars_1
# Out:
#                cod_eu cod_aca         nom_edar      fecha  Arsènic dissolt  \
# 0    ES9081940001010E    DBSS            BESÒS 2009-01-01           0.0034
# 1    ES9083010001010E    DGVC  GAVÀ/VILADECANS 2009-01-01           0.0065
# 2    ES9170790005010E    DGIR           GIRONA 2009-01-01           0.0014
# 3    ES9080960001010E    DGRA       GRANOLLERS 2009-01-01           0.0015
# 4    ES9081050001010E    DLLL      LA LLAGOSTA 2009-01-01           0.0017
# ..                ...     ...              ...        ...              ...
# 244  ES9171520008010E    DRSS            ROSES 2016-01-01           0.0030
# 245  ES9251200006050E    DLLL         L'ESCALA 2016-01-01           0.0020
# 246  ES9083010001010E    DFIG         FIGUERES 2016-01-01              NaN
# 247  ES9082980001010E    DVIC              VIC 2016-01-01              NaN
# 248  ES9080960001010E    DGIR           GIRONA 2016-01-01              NaN
#
#      Cadmi dissolt  Crom dissolt  Coure dissolt  Mercuri dissolt  \
# ...

# %%
#Add rows from prtr_edars_2 to prtr_edars
prtr_edars = pd.concat([prtr_edars_1, prtr_edars_2], ignore_index=True)
prtr_edars.head()
# Out:
#              cod_eu cod_aca         nom_edar      fecha  Arsènic dissolt  \
# 0  ES9081940001010E    DBSS            BESÒS 2009-01-01           0.0034
# 1  ES9083010001010E    DGVC  GAVÀ/VILADECANS 2009-01-01           0.0065
# 2  ES9170790005010E    DGIR           GIRONA 2009-01-01           0.0014
# 3  ES9080960001010E    DGRA       GRANOLLERS 2009-01-01           0.0015
# 4  ES9081050001010E    DLLL      LA LLAGOSTA 2009-01-01           0.0017
#
#    Cadmi dissolt  Crom dissolt  Coure dissolt  Mercuri dissolt  \
# 0            NaN        0.0039         0.0030              NaN
# 1            NaN        0.0066         0.0129              NaN
# 2            NaN           NaN         0.0213              NaN
# 3            NaN        0.0078         0.0052              NaN
# 4            NaN        0.0036         0.0043              NaN
#
#    Niquel dissolt  ...  t-octilfenol  DBO 5 dies  propazina µg/l  \
# 0          0.0112  ...           NaN         NaN             NaN
# ...

# %%
analitiques_sistemes = pd.read_excel(path+'edars_analitiques_sistemes_2.xlsx')
analitiques_sistemes.head()
# Out:
#   cod_aca nom_edar  any_dades   cabal_diari  DBO 5 dies influent  \
# 0    DABR   ABRERA       2010  18140.610959                  NaN
# 1    DABR   ABRERA       2011  16261.693151           285.833333
# 2    DABR   ABRERA       2012  14575.366120           285.588235
# 3    DABR   ABRERA       2013  15390.208219           179.520989
# 4    DABR   ABRERA       2014  15725.142466                  NaN
#
#    DBO 5 dies effluent  Nitrogen Total influent  Nitrogen Total effluent  \
# 0            18.541667                54.206666                31.692917
# 1            10.333333                54.934584                17.215417
# 2            52.336471                12.272353                37.411765
# 3            16.500000                42.100001                12.191667
# 4                  NaN                      NaN                      NaN
#
#    Fòsfor total influent  Fòsfor total effluent
# 0               7.275000               2.045833
# ...

# %%
#add datetime from year
analitiques_sistemes['fecha'] = pd.to_datetime(analitiques_sistemes['any_dades'], format='%Y')

# %%
influent = analitiques_sistemes.copy()
effluent = analitiques_sistemes

# %%
#Delete all the columns which name contains 'influent'
effluent = effluent[effluent.columns.drop(list(effluent.filter(regex='influent')))]
#Delete all the columns which name contains 'effluent'
influent = influent[influent.columns.drop(list(influent.filter(regex='effluent')))]

#Rename columns to remove 'influent' or 'effluent' from the name
influent.columns = influent.columns.str.replace(' influent', '')
effluent.columns = effluent.columns.str.replace(' effluent', '')

# %%
influent = influent.copy()
effluent = effluent.copy()

#Add column 'codi_eu' to influent and effluent
influent['cod_eu'] = influent['nom_edar'].map(edar_dict)
effluent['cod_eu'] = effluent['nom_edar'].map(edar_dict)

# %%
#append prtr edars to effluent
data = pd.concat([effluent, prtr_edars], ignore_index=True)
data.head()
# Out:
#   cod_aca nom_edar  any_dades   cabal_diari  DBO 5 dies  Nitrogen Total  \
# 0    DABR   ABRERA     2010.0  18140.610959   18.541667       31.692917
# 1    DABR   ABRERA     2011.0  16261.693151   10.333333       17.215417
# 2    DABR   ABRERA     2012.0  14575.366120   52.336471       37.411765
# 3    DABR   ABRERA     2013.0  15390.208219   16.500000       12.191667
# 4    DABR   ABRERA     2014.0  15725.142466         NaN             NaN
#
#    Fòsfor total      fecha            cod_eu  Arsènic dissolt  ...  \
# 0      2.045833 2010-01-01  ES9080010001010E              NaN  ...
# 1      3.287500 2011-01-01  ES9080010001010E              NaN  ...
# 2      2.476471 2012-01-01  ES9080010001010E              NaN  ...
# 3      0.699167 2013-01-01  ES9080010001010E              NaN  ...
# 4           NaN 2014-01-01  ES9080010001010E              NaN  ...
#
#    trifenilestaño µg/l  npeoe=0  t-octilfenol  propazina µg/l  Terbutilazina  \
# ...

# %%
#Read from sql pandas dataframe
command = "SELECT * FROM edar_scarce_2 WHERE \"Concentration\" = 'Individual value'"

engine = create_engine('postgresql://traca_user:EdificiH2O!@217.61.208.188:5432/traca_1')

scarce_2 = pd.read_sql(command, con=engine)

Code_to_cod_eu = {
    'DEPABR-O': 'ES9080010001010E', #Abrera
    'DEPABR-I': 'ES9080010001010E', #Abrera
    'DEPIGU-O': 'ES9083020001010E', #Igualada
    'DEPIGU-I': 'ES9083020001010E', #Igualada
    'DEPIGU-O': 'ES9083020001010E', #Igualada
    'DEPMAN-O': 'ES9081130006010E', #Manresa
    'DEPMAN-I': 'ES9081130006010E', #Manresa
}

#In scarce, add cod_eu column using Code_to_cod_eu dictionary
scarce_2['cod_eu'] = scarce_2['Code'].map(Code_to_cod_eu)

#Divide value by 1000 (convert to micrograms/L to milligrams/L)
scarce_2['Value'] = scarce_2['Value'].div(1000)

#Convert Unit to mg/L
scarce_2['Unit'] = 'mg/L'
#Parse columns Day, Month and Year to date
scarce_2['fecha'] = pd.to_datetime(scarce_2[['Day', 'Month', 'Year']])

#Keep only columns 'Substance name', 'Value', 'cod_eu', 'Unit', 'fecha', 'Code'
scarce_2 = scarce_2[['Substance name', 'Value', 'cod_eu', 'Unit', 'fecha', 'Code']]

#Divide between effluent and influent
scarce_2_effluent = scarce_2[scarce_2['Code'].str.contains('O')]
scarce_2_influent = scarce_2[scarce_2['Code'].str.contains('I')]

#From rows that has same cod_eu and date, convert to one row with one substance per column
scarce_2_effluent_rows = scarce_2_effluent.pivot_table(index=['cod_eu', 'fecha'], columns='Substance name', values='Value').reset_index()

#add rows from scarce_effluent_rows to data
all_effluent_data = pd.concat([data, scarce_2_effluent_rows], ignore_index=True)

# %%
#Read from sql pandas dataframe
command = "SELECT * FROM edar_scarce WHERE \"Concentration\" = 'Individual value'"

scarce = pd.read_sql(command, con=engine)

#In scarce, add cod_eu column using Code_to_cod_eu dictionary
scarce['cod_eu'] = scarce['Code'].map(Code_to_cod_eu)

#Divide value by 1000 (convert to micrograms/L to milligrams/L)
scarce['Value'] = scarce['Value'].div(1000)

#Convert Unit to mg/L
scarce['Unit'] = 'mg/L'

#Parse columns Day, Month and Year to date
scarce['fecha'] = pd.to_datetime(scarce[['Day', 'Month', 'Year']])

#Keep only columns 'Substance name', 'Value', 'cod_eu', 'Unit', 'fecha', 'Code'
scarce = scarce[['Substance name', 'Value', 'cod_eu', 'Unit', 'fecha', 'Code']]

#Divide between effluent and influent
scarce_effluent = scarce[scarce['Code'].str.contains('O')]
scarce_influent = scarce[scarce['Code'].str.contains('I')]

#From rows that has same cod_eu and date, convert to one row with one substance per column
scarce_effluent_rows = scarce_effluent.pivot_table(index=['cod_eu', 'fecha'], columns='Substance name', values='Value').reset_index()

#add rows from scarce_effluent_rows to data
all_effluent_data = pd.concat([all_effluent_data, scarce_effluent_rows], ignore_index=True)

# %%
all_effluent_data
# Out:
#      cod_aca nom_edar  any_dades   cabal_diari  DBO 5 dies  Nitrogen Total  \
# 0       DABR   ABRERA     2010.0  18140.610959   18.541667       31.692917
# 1       DABR   ABRERA     2011.0  16261.693151   10.333333       17.215417
# 2       DABR   ABRERA     2012.0  14575.366120   52.336471       37.411765
# 3       DABR   ABRERA     2013.0  15390.208219   16.500000       12.191667
# 4       DABR   ABRERA     2014.0  15725.142466         NaN             NaN
# ...      ...      ...        ...           ...         ...             ...
# 5544     NaN      NaN        NaN           NaN         NaN             NaN
# 5545     NaN      NaN        NaN           NaN         NaN             NaN
# 5546     NaN      NaN        NaN           NaN         NaN             NaN
# 5547     NaN      NaN        NaN           NaN         NaN             NaN
# 5548     NaN      NaN        NaN           NaN         NaN             NaN
#
# ...

# %%
#Filter where cod_eu is not null and drop cabal_diari and any_dades columns
all_effluent_data_filtered = all_effluent_data[all_effluent_data['cod_eu'].notna()].reset_index()
all_effluent_data_filtered.drop(['cabal_diari', 'any_dades', 'conductivitat 20ºc µs/cm', 'index'], axis=1, inplace=True)

#in columns names, replace 'µg' by 'mg'
all_effluent_data_filtered.columns = all_effluent_data_filtered.columns.str.replace('µg', 'mg')
all_effluent_data_filtered
# Out:
#      cod_aca nom_edar  DBO 5 dies  Nitrogen Total  Fòsfor total      fecha  \
# 0       DABR   ABRERA   18.541667       31.692917      2.045833 2010-01-01
# 1       DABR   ABRERA   10.333333       17.215417      3.287500 2011-01-01
# 2       DABR   ABRERA   52.336471       37.411765      2.476471 2012-01-01
# 3       DABR   ABRERA   16.500000       12.191667      0.699167 2013-01-01
# 4       DABR   ABRERA         NaN             NaN           NaN 2014-01-01
# ...      ...      ...         ...             ...           ...        ...
# 1791     NaN      NaN         NaN             NaN           NaN 2011-09-26
# 1792     NaN      NaN         NaN             NaN           NaN 2011-10-13
# 1793     NaN      NaN         NaN             NaN           NaN 2010-10-23
# 1794     NaN      NaN         NaN             NaN           NaN 2011-09-26
# 1795     NaN      NaN         NaN             NaN           NaN 2011-10-18
#
# ...

# %%
#Add column "Unit" with value "mg/L"
all_effluent_data_filtered['Unit'] = 'mg/L'

# %%
#pivot wide to long format
all_effluent_data_long = pd.melt(all_effluent_data_filtered, id_vars=['cod_eu', 'cod_aca', 'nom_edar', 'fecha', "Unit"], var_name='Substance name', value_name='Value')
#Filter where Value is not null
all_effluent_data_long = all_effluent_data_long[all_effluent_data_long['Value'].notna()]
all_effluent_data_long
# Out:
#                   cod_eu cod_aca nom_edar      fecha  Unit Substance name  \
# 0       ES9080010001010E    DABR   ABRERA 2010-01-01  mg/L     DBO 5 dies
# 1       ES9080010001010E    DABR   ABRERA 2011-01-01  mg/L     DBO 5 dies
# 2       ES9080010001010E    DABR   ABRERA 2012-01-01  mg/L     DBO 5 dies
# 3       ES9080010001010E    DABR   ABRERA 2013-01-01  mg/L     DBO 5 dies
# 5       ES9080010001010E    DABR   ABRERA 2015-01-01  mg/L     DBO 5 dies
# ...                  ...     ...      ...        ...   ...            ...
# 161637  ES9083020001010E     NaN      NaN 2010-10-23  mg/L    Venlafaxina
# 161639  ES9083020001010E     NaN      NaN 2011-10-18  mg/L    Venlafaxina
# 163428  ES9080010001010E     NaN      NaN 2011-10-04  mg/L        Alaclor
# 163431  ES9081130006010E     NaN      NaN 2011-09-26  mg/L        Alaclor
# 163434  ES9083020001010E     NaN      NaN 2011-09-26  mg/L        Alaclor
#
#             Value
# 0       18.541667
# 1       10.333333
# 2       52.336471
# ...

# %%
#Drow duplicates in cod_eu and fecha and Substance name
all_effluent_data_long = all_effluent_data_long.drop_duplicates(subset=['cod_eu', 'fecha', 'Substance name', 'Value'])

# %%
all_effluent_data_long
# Out:
#                   cod_eu cod_aca nom_edar      fecha  Unit Substance name  \
# 0       ES9080010001010E    DABR   ABRERA 2010-01-01  mg/L     DBO 5 dies
# 1       ES9080010001010E    DABR   ABRERA 2011-01-01  mg/L     DBO 5 dies
# 2       ES9080010001010E    DABR   ABRERA 2012-01-01  mg/L     DBO 5 dies
# 3       ES9080010001010E    DABR   ABRERA 2013-01-01  mg/L     DBO 5 dies
# 5       ES9080010001010E    DABR   ABRERA 2015-01-01  mg/L     DBO 5 dies
# ...                  ...     ...      ...        ...   ...            ...
# 161629  ES9083020001010E     NaN      NaN 2010-10-23  mg/L    Venlafaxina
# 161631  ES9083020001010E     NaN      NaN 2011-10-18  mg/L    Venlafaxina
# 163428  ES9080010001010E     NaN      NaN 2011-10-04  mg/L        Alaclor
# 163431  ES9081130006010E     NaN      NaN 2011-09-26  mg/L        Alaclor
# 163434  ES9083020001010E     NaN      NaN 2011-09-26  mg/L        Alaclor
#
#             Value
# 0       18.541667
# 1       10.333333
# 2       52.336471
# ...

# %%
#Upload to sql
all_effluent_data_long.to_sql('edars_effluent', engine, if_exists='replace', index=False)
# Out:
# 302
